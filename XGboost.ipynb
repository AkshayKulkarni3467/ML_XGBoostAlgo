# %%
pip install scikit-learn

# %%
pip install --force-reinstall graphviz==0.18

# %%
pip install xgboost

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import balanced_accuracy_score,roc_auc_score,make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix

# %%
pip install --upgrade scikit-learn

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
df = pd.read_excel('./python_practice/datasets/TelcoChurn.xlsx')

# %%
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %% [markdown]
# ### Deleting columns which are not useful for classification

# %%
df.drop('CustomerID',axis=1,inplace=True)
df.head()
# Out:
#    Count        Country       State         City  Zip Code  \
# 0      1  United States  California  Los Angeles     90003
# 1      1  United States  California  Los Angeles     90005
# 2      1  United States  California  Los Angeles     90006
# 3      1  United States  California  Los Angeles     90010
# 4      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  ...  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No  ...
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No  ...
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No  ...
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No  ...
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No  ...
#
#          Contract Paperless Billing             Payment Method  \
# 0  Month-to-month               Yes               Mailed check
# ...

# %% [markdown]
# #### Deleting columns with only one value

# %%
df.drop(['Count','Country','State','Churn Label','Churn Score','CLTV','Churn Reason'],axis=1,inplace=True)
df.head()
# Out:
#           City  Zip Code                Lat Long   Latitude   Longitude  \
# 0  Los Angeles     90003  33.964131, -118.272783  33.964131 -118.272783
# 1  Los Angeles     90005   34.059281, -118.30742  34.059281 -118.307420
# 2  Los Angeles     90006  34.048013, -118.293953  34.048013 -118.293953
# 3  Los Angeles     90010  34.062125, -118.315709  34.062125 -118.315709
# 4  Los Angeles     90015  34.039224, -118.266293  34.039224 -118.266293
#
#    Gender Senior Citizen Partner Dependents  Tenure Months  ...  \
# 0    Male             No      No         No              2  ...
# 1  Female             No      No        Yes              2  ...
# 2  Female             No      No        Yes              8  ...
# 3  Female             No     Yes        Yes             28  ...
# 4    Male             No      No        Yes             49  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# ...

# %%
df.drop(['Lat Long'],axis=1, inplace=True)
df.head()
# Out:
#           City  Zip Code   Latitude   Longitude  Gender Senior Citizen  \
# 0  Los Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service  ... Device Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# ...

# %% [markdown]
# #### Filling whitespace in city with underscore

# %%
df['City'].replace(' ','_',regex=True,inplace = True)

# %%
df.head()
# Out:
#           City  Zip Code   Latitude   Longitude  Gender Senior Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service  ... Device Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# ...

# %% [markdown]
# #### replacing whitespace in columns with underscore

# %%
df.columns = df.columns.str.replace(' ','_')
df.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Device_Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech_Support Streaming_TV Streaming_Movies        Contract  \
# ...

# %%
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges         object
# Churn_Value            int64
# dtype: object

# %%
len(df.loc[df['Total_Charges']==' '])
# Out:
# 11

# %% [markdown]
# #### only 11 rows with total charges = 0

# %%
df.loc[(df['Total_Charges'] == ' '),'Total_Charges']=0

# %%
df.loc[df['Tenure_Months']==0]
# Out:
#                 City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 2234  San_Bernardino     92408  34.084909 -117.258107  Female             No
# 2438    Independence     93526  36.869584 -118.189241    Male             No
# 2568       San_Mateo     94401  37.590421 -122.306467  Female             No
# 2667       Cupertino     95014  37.306612 -122.080621    Male             No
# 2856        Redcrest     95569  40.363446 -123.835041  Female             No
# 4331     Los_Angeles     90029  34.089953 -118.294824    Male             No
# 4687        Sun_City     92585  33.739412 -117.173334    Male             No
# 5104      Ben_Lomond     95005  37.078873 -122.090386  Female             No
# 5719        La_Verne     91750  34.144703 -117.770299    Male             No
# 6772            Bell     90201  33.970343 -118.171368  Female             No
# 6840      Wilmington     90744  33.782068 -118.262263    Male             No
#
# ...

# %%
df['Total_Charges'] = pd.to_numeric(df['Total_Charges'])

# %%
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges        float64
# Churn_Value            int64
# dtype: object

# %%
df.replace(' ','_',regex= True, inplace=True)

# %%
df.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Device_Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech_Support Streaming_TV Streaming_Movies        Contract  \
# ...

# %%
X = df.drop('Churn_Value',axis=1).copy()
X.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Online_Backup  \
# 0      No         No              2           Yes  ...           Yes
# 1      No        Yes              2           Yes  ...            No
# 2      No        Yes              8           Yes  ...            No
# 3     Yes        Yes             28           Yes  ...            No
# 4      No        Yes             49           Yes  ...           Yes
#
#   Device_Protection Tech_Support Streaming_TV Streaming_Movies  \
# ...

# %%
y = df["Churn_Value"].copy()
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Churn_Value, dtype: int64

# %%
X['Online_Backup'].unique()
# Out:
# array(['Yes', 'No', 'No_internet_service'], dtype=object)

# %%
X_encoded1 = pd.get_dummies(X, columns=['City',
                                        'Gender',
                                        'Senior_Citizen',
                                        'Partner',
                                        'Dependents',
                                        'Phone_Service',
                                        'Multiple_Lines',
                                        'Internet_Service',
                                        'Online_Security',
                                        'Online_Backup',
                                        'Device_Protection',
                                        'Tech_Support',
                                        'Streaming_TV',
                                        'Streaming_Movies',
                                        'Contract',
                                        'Paperless_Billing',
                                        'Payment_Method'
                                       ],dtype=int)

# %%
X_encoded1.head()
# Out:
#    Zip_Code   Latitude   Longitude  Tenure_Months  Monthly_Charges  \
# 0     90003  33.964131 -118.272783              2            53.85
# 1     90005  34.059281 -118.307420              2            70.70
# 2     90006  34.048013 -118.293953              8            99.65
# 3     90010  34.062125 -118.315709             28           104.80
# 4     90015  34.039224 -118.266293             49           103.70
#
#    Total_Charges  City_Acampo  City_Acton  City_Adelanto  City_Adin  ...  \
# 0         108.15            0           0              0          0  ...
# 1         151.65            0           0              0          0  ...
# 2         820.50            0           0              0          0  ...
# 3        3046.05            0           0              0          0  ...
# 4        5036.30            0           0              0          0  ...
#
#    Streaming_Movies_Yes  Contract_Month-to-month  Contract_One_year  \
# ...

# %%
y.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
sum(y)/len(y)
# Out:
# 0.2653698707936959

# %% [markdown]
# ##### So we see that 27% of the people left the company. Hence this data is imbalanced

# %%
X_train,X_test,y_train,y_test = train_test_split(X_encoded1,y,random_state=42, stratify=y)

# %%
sum(y_train)/len(y_train)
# Out:
# 0.2654297614539947

# %%
sum(y_test)/len(y_test)
# Out:
# 0.26519023282226006

# %% [markdown]
# ##### Creating a xgboost algorithm to predict if the person has left the company or not

# %%
clf_xgb = xgb.XGBClassifier(
    seed = 42,
    objective = 'binary:logistic',
    gamma= 0.25,
    learning_rate = 0.1,
    max_depth = 4,
    reg_lambda = 10,
    scale_pos_weight = 3,
    subsample = 0.9,
    colsample_bytree = 0.5
)

clf_xgb.fit(
    X_train,
    y_train,
    verbose = True,
    early_stopping_rounds = 10,
    eval_metric = 'aucpr',
    eval_set = [(X_test,y_test)]
)
# Out:
# c:\Users\aksha\anaconda2\envs\python_eda\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# c:\Users\aksha\anaconda2\envs\python_eda\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-aucpr:0.54553
# [1]	validation_0-aucpr:0.56880
# [2]	validation_0-aucpr:0.62226
# [3]	validation_0-aucpr:0.62876
# [4]	validation_0-aucpr:0.63409
# [5]	validation_0-aucpr:0.63606
# [6]	validation_0-aucpr:0.63522
# [7]	validation_0-aucpr:0.63449
# [8]	validation_0-aucpr:0.63650
# [9]	validation_0-aucpr:0.63752
# [10]	validation_0-aucpr:0.63786
# [11]	validation_0-aucpr:0.63795
# [12]	validation_0-aucpr:0.65322
# ...

# %% [markdown]
# ##### Plotting a confusion matrix to see the true positives and true negatives

# %%
predictions = clf_xgb.predict(X_test)
cm = confusion_matrix(y_test, predictions, labels=clf_xgb.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=['Did not leave','Left'])
disp.plot()

plt.show()

# %%
print(f'Hence the true positives are : {(933/(933+361))*100}')
print(f'Hence the false positives are: {(361/(933+361))*100}')
print(f'Hence the true negatives are: {(388/(388+79))*100}')
print(f'Hence the false negatives are: {(79/(388+79))*100}')
# Out:
# Hence the true positives are : 72.10200927357032
# Hence the false positives are: 27.89799072642968
# Hence the true negatives are: 83.08351177730194
# Hence the false negatives are: 16.916488222698074
